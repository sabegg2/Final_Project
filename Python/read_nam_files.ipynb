# %% [markdown]
# # Reading Wind Data from NAM Files
# - North American Mesoscale Forecast System (NAM) [12 km]: The North American Mesoscale Forecast System (NAM) is one of the major regional weather forecast models run by the National Centers for Environmental Prediction (NCEP) for producing weather forecasts. Dozens of weather parameters are available from the NAM grids, from temperature and precipitation to lightning and turbulent kinetic energy. The NAM generates multiple grids (or domains) of weather forecasts over the North American continent at various horizontal resolutions. High-resolution forecasts are generated within the NAM using additional numerical weather models. These high-resolution forecast windows are generated over fixed regions and are occasionally run to follow significant weather events, like hurricanes. This dataset contains a 12 km horizontal resolution Lambert Conformal grid covering the Continental United States (CONUS) domain. It is run four times daily at 00z, 06z, 12z and 18z out to 84 hours with a 1 hour temporal resolution.
# - Since the 0-hour forecast is the initial state of the model, it should match the analysis because it's based on the same observed data. Differences, if any, are generally minimal and result from the interpolation process in the model.
# - https://www.ncei.noaa.gov/products/weather-climate-models/north-american-mesoscale
# - https://www.ncei.noaa.gov/has/HAS.FileAppRouter?datasetname=NAMANL218&subqueryby=STATION&applname=&outdest=FILE

# %%
# Import modules
import pygrib
import numpy as np
import pandas as pd
import os
from datetime import datetime
import requests
from bs4 import BeautifulSoup
import tarfile

# %% [markdown]
# # First, get .tar files from web download, extract the .grb2 files

# %%
# URL of the page with file listings
base_url = 'https://www.ncei.noaa.gov/pub/has/model/HAS012561864/'

# Fetch the webpage
response = requests.get(base_url)

# Parse the HTML using BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Directory to save the files
download_dir = 'downloaded_files'
os.makedirs(download_dir, exist_ok=True)
# Directory to extract the contents
extract_dir = 'extracted_files'
os.makedirs(extract_dir, exist_ok=True)

# Find all the links to .tar files
for link in soup.find_all('a', href=True):
    file_url = link['href']
    if file_url.endswith('.tar'):
        full_url = base_url + file_url
        file_name = os.path.join(download_dir, file_url.split('/')[-1])
        print(file_name)
        # Download the file
        print(f'Downloading {full_url}')
     #   file_response = requests.get(full_url)   # uncomment these lines to download them all - takes awhile!
     #   with open(file_name, 'wb') as file:
     #       file.write(file_response.content)
     # Open and extract the tar file
        print(f'Downloaded: {file_name}')
        extract_folder = extract_dir+'/'+file_url.strip('.tar')
        os.makedirs(extract_folder, exist_ok=True)
     #   with tarfile.open(file_name, 'r') as tar:
     #       tar.extractall(path=extract_folder)
        print(f'Extracted: {file_name}')
     #   os.remove(file_name) # delete file permanently
        print(f'Deleted: {file_name}')
# Out:
# downloaded_files/nam_218_2024020812.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024020812.g2.tar
# Downloaded: downloaded_files/nam_218_2024020812.g2.tar
# Extracted: downloaded_files/nam_218_2024020812.g2.tar
# Deleted: downloaded_files/nam_218_2024020812.g2.tar
# downloaded_files/nam_218_2024020818.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024020818.g2.tar
# Downloaded: downloaded_files/nam_218_2024020818.g2.tar
# Extracted: downloaded_files/nam_218_2024020818.g2.tar
# Deleted: downloaded_files/nam_218_2024020818.g2.tar
# downloaded_files/nam_218_2024020912.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024020912.g2.tar
# Downloaded: downloaded_files/nam_218_2024020912.g2.tar
# Extracted: downloaded_files/nam_218_2024020912.g2.tar
# Deleted: downloaded_files/nam_218_2024020912.g2.tar
# downloaded_files/nam_218_2024020918.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024020918.g2.tar
# Downloaded: downloaded_files/nam_218_2024020918.g2.tar
# Extracted: downloaded_files/nam_218_2024020918.g2.tar
# Deleted: downloaded_files/nam_218_2024020918.g2.tar
# downloaded_files/nam_218_2024021012.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021012.g2.tar
# Downloaded: downloaded_files/nam_218_2024021012.g2.tar
# Extracted: downloaded_files/nam_218_2024021012.g2.tar
# Deleted: downloaded_files/nam_218_2024021012.g2.tar
# downloaded_files/nam_218_2024021018.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021018.g2.tar
# Downloaded: downloaded_files/nam_218_2024021018.g2.tar
# Extracted: downloaded_files/nam_218_2024021018.g2.tar
# Deleted: downloaded_files/nam_218_2024021018.g2.tar
# downloaded_files/nam_218_2024021112.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021112.g2.tar
# Downloaded: downloaded_files/nam_218_2024021112.g2.tar
# Extracted: downloaded_files/nam_218_2024021112.g2.tar
# Deleted: downloaded_files/nam_218_2024021112.g2.tar
# downloaded_files/nam_218_2024021118.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021118.g2.tar
# Downloaded: downloaded_files/nam_218_2024021118.g2.tar
# Extracted: downloaded_files/nam_218_2024021118.g2.tar
# Deleted: downloaded_files/nam_218_2024021118.g2.tar
# downloaded_files/nam_218_2024021212.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021212.g2.tar
# Downloaded: downloaded_files/nam_218_2024021212.g2.tar
# Extracted: downloaded_files/nam_218_2024021212.g2.tar
# Deleted: downloaded_files/nam_218_2024021212.g2.tar
# downloaded_files/nam_218_2024021218.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021218.g2.tar
# Downloaded: downloaded_files/nam_218_2024021218.g2.tar
# Extracted: downloaded_files/nam_218_2024021218.g2.tar
# Deleted: downloaded_files/nam_218_2024021218.g2.tar
# downloaded_files/nam_218_2024021312.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021312.g2.tar
# Downloaded: downloaded_files/nam_218_2024021312.g2.tar
# Extracted: downloaded_files/nam_218_2024021312.g2.tar
# Deleted: downloaded_files/nam_218_2024021312.g2.tar
# downloaded_files/nam_218_2024021318.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021318.g2.tar
# Downloaded: downloaded_files/nam_218_2024021318.g2.tar
# Extracted: downloaded_files/nam_218_2024021318.g2.tar
# Deleted: downloaded_files/nam_218_2024021318.g2.tar
# downloaded_files/nam_218_2024021412.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021412.g2.tar
# Downloaded: downloaded_files/nam_218_2024021412.g2.tar
# Extracted: downloaded_files/nam_218_2024021412.g2.tar
# Deleted: downloaded_files/nam_218_2024021412.g2.tar
# downloaded_files/nam_218_2024021418.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021418.g2.tar
# Downloaded: downloaded_files/nam_218_2024021418.g2.tar
# Extracted: downloaded_files/nam_218_2024021418.g2.tar
# Deleted: downloaded_files/nam_218_2024021418.g2.tar
# downloaded_files/nam_218_2024021512.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021512.g2.tar
# Downloaded: downloaded_files/nam_218_2024021512.g2.tar
# Extracted: downloaded_files/nam_218_2024021512.g2.tar
# Deleted: downloaded_files/nam_218_2024021512.g2.tar
# downloaded_files/nam_218_2024021518.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021518.g2.tar
# Downloaded: downloaded_files/nam_218_2024021518.g2.tar
# Extracted: downloaded_files/nam_218_2024021518.g2.tar
# Deleted: downloaded_files/nam_218_2024021518.g2.tar
# downloaded_files/nam_218_2024021612.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021612.g2.tar
# Downloaded: downloaded_files/nam_218_2024021612.g2.tar
# Extracted: downloaded_files/nam_218_2024021612.g2.tar
# Deleted: downloaded_files/nam_218_2024021612.g2.tar
# downloaded_files/nam_218_2024021618.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021618.g2.tar
# Downloaded: downloaded_files/nam_218_2024021618.g2.tar
# Extracted: downloaded_files/nam_218_2024021618.g2.tar
# Deleted: downloaded_files/nam_218_2024021618.g2.tar
# downloaded_files/nam_218_2024021712.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021712.g2.tar
# Downloaded: downloaded_files/nam_218_2024021712.g2.tar
# Extracted: downloaded_files/nam_218_2024021712.g2.tar
# Deleted: downloaded_files/nam_218_2024021712.g2.tar
# downloaded_files/nam_218_2024021718.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021718.g2.tar
# Downloaded: downloaded_files/nam_218_2024021718.g2.tar
# Extracted: downloaded_files/nam_218_2024021718.g2.tar
# Deleted: downloaded_files/nam_218_2024021718.g2.tar
# downloaded_files/nam_218_2024021812.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021812.g2.tar
# Downloaded: downloaded_files/nam_218_2024021812.g2.tar
# Extracted: downloaded_files/nam_218_2024021812.g2.tar
# Deleted: downloaded_files/nam_218_2024021812.g2.tar
# downloaded_files/nam_218_2024021818.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021818.g2.tar
# Downloaded: downloaded_files/nam_218_2024021818.g2.tar
# Extracted: downloaded_files/nam_218_2024021818.g2.tar
# Deleted: downloaded_files/nam_218_2024021818.g2.tar
# downloaded_files/nam_218_2024021912.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021912.g2.tar
# Downloaded: downloaded_files/nam_218_2024021912.g2.tar
# Extracted: downloaded_files/nam_218_2024021912.g2.tar
# Deleted: downloaded_files/nam_218_2024021912.g2.tar
# downloaded_files/nam_218_2024021918.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024021918.g2.tar
# Downloaded: downloaded_files/nam_218_2024021918.g2.tar
# Extracted: downloaded_files/nam_218_2024021918.g2.tar
# Deleted: downloaded_files/nam_218_2024021918.g2.tar
# downloaded_files/nam_218_2024022012.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022012.g2.tar
# Downloaded: downloaded_files/nam_218_2024022012.g2.tar
# Extracted: downloaded_files/nam_218_2024022012.g2.tar
# Deleted: downloaded_files/nam_218_2024022012.g2.tar
# downloaded_files/nam_218_2024022018.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022018.g2.tar
# Downloaded: downloaded_files/nam_218_2024022018.g2.tar
# Extracted: downloaded_files/nam_218_2024022018.g2.tar
# Deleted: downloaded_files/nam_218_2024022018.g2.tar
# downloaded_files/nam_218_2024022112.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022112.g2.tar
# Downloaded: downloaded_files/nam_218_2024022112.g2.tar
# Extracted: downloaded_files/nam_218_2024022112.g2.tar
# Deleted: downloaded_files/nam_218_2024022112.g2.tar
# downloaded_files/nam_218_2024022118.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022118.g2.tar
# Downloaded: downloaded_files/nam_218_2024022118.g2.tar
# Extracted: downloaded_files/nam_218_2024022118.g2.tar
# Deleted: downloaded_files/nam_218_2024022118.g2.tar
# downloaded_files/nam_218_2024022212.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022212.g2.tar
# Downloaded: downloaded_files/nam_218_2024022212.g2.tar
# Extracted: downloaded_files/nam_218_2024022212.g2.tar
# Deleted: downloaded_files/nam_218_2024022212.g2.tar
# downloaded_files/nam_218_2024022218.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022218.g2.tar
# Downloaded: downloaded_files/nam_218_2024022218.g2.tar
# Extracted: downloaded_files/nam_218_2024022218.g2.tar
# Deleted: downloaded_files/nam_218_2024022218.g2.tar
# downloaded_files/nam_218_2024022312.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022312.g2.tar
# Downloaded: downloaded_files/nam_218_2024022312.g2.tar
# Extracted: downloaded_files/nam_218_2024022312.g2.tar
# Deleted: downloaded_files/nam_218_2024022312.g2.tar
# downloaded_files/nam_218_2024022318.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022318.g2.tar
# Downloaded: downloaded_files/nam_218_2024022318.g2.tar
# Extracted: downloaded_files/nam_218_2024022318.g2.tar
# Deleted: downloaded_files/nam_218_2024022318.g2.tar
# downloaded_files/nam_218_2024022412.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022412.g2.tar
# Downloaded: downloaded_files/nam_218_2024022412.g2.tar
# Extracted: downloaded_files/nam_218_2024022412.g2.tar
# Deleted: downloaded_files/nam_218_2024022412.g2.tar
# downloaded_files/nam_218_2024022418.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022418.g2.tar
# Downloaded: downloaded_files/nam_218_2024022418.g2.tar
# Extracted: downloaded_files/nam_218_2024022418.g2.tar
# Deleted: downloaded_files/nam_218_2024022418.g2.tar
# downloaded_files/nam_218_2024022512.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022512.g2.tar
# Downloaded: downloaded_files/nam_218_2024022512.g2.tar
# Extracted: downloaded_files/nam_218_2024022512.g2.tar
# Deleted: downloaded_files/nam_218_2024022512.g2.tar
# downloaded_files/nam_218_2024022518.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022518.g2.tar
# Downloaded: downloaded_files/nam_218_2024022518.g2.tar
# Extracted: downloaded_files/nam_218_2024022518.g2.tar
# Deleted: downloaded_files/nam_218_2024022518.g2.tar
# downloaded_files/nam_218_2024022612.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022612.g2.tar
# Downloaded: downloaded_files/nam_218_2024022612.g2.tar
# Extracted: downloaded_files/nam_218_2024022612.g2.tar
# Deleted: downloaded_files/nam_218_2024022612.g2.tar
# downloaded_files/nam_218_2024022618.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022618.g2.tar
# Downloaded: downloaded_files/nam_218_2024022618.g2.tar
# Extracted: downloaded_files/nam_218_2024022618.g2.tar
# Deleted: downloaded_files/nam_218_2024022618.g2.tar
# downloaded_files/nam_218_2024022712.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022712.g2.tar
# Downloaded: downloaded_files/nam_218_2024022712.g2.tar
# Extracted: downloaded_files/nam_218_2024022712.g2.tar
# Deleted: downloaded_files/nam_218_2024022712.g2.tar
# downloaded_files/nam_218_2024022718.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022718.g2.tar
# Downloaded: downloaded_files/nam_218_2024022718.g2.tar
# Extracted: downloaded_files/nam_218_2024022718.g2.tar
# Deleted: downloaded_files/nam_218_2024022718.g2.tar
# downloaded_files/nam_218_2024022812.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022812.g2.tar
# Downloaded: downloaded_files/nam_218_2024022812.g2.tar
# Extracted: downloaded_files/nam_218_2024022812.g2.tar
# Deleted: downloaded_files/nam_218_2024022812.g2.tar
# downloaded_files/nam_218_2024022818.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022818.g2.tar
# Downloaded: downloaded_files/nam_218_2024022818.g2.tar
# Extracted: downloaded_files/nam_218_2024022818.g2.tar
# Deleted: downloaded_files/nam_218_2024022818.g2.tar
# downloaded_files/nam_218_2024022912.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022912.g2.tar
# Downloaded: downloaded_files/nam_218_2024022912.g2.tar
# Extracted: downloaded_files/nam_218_2024022912.g2.tar
# Deleted: downloaded_files/nam_218_2024022912.g2.tar
# downloaded_files/nam_218_2024022918.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024022918.g2.tar
# Downloaded: downloaded_files/nam_218_2024022918.g2.tar
# Extracted: downloaded_files/nam_218_2024022918.g2.tar
# Deleted: downloaded_files/nam_218_2024022918.g2.tar
# downloaded_files/nam_218_2024030112.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024030112.g2.tar
# Downloaded: downloaded_files/nam_218_2024030112.g2.tar
# Extracted: downloaded_files/nam_218_2024030112.g2.tar
# Deleted: downloaded_files/nam_218_2024030112.g2.tar
# downloaded_files/nam_218_2024030118.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024030118.g2.tar
# Downloaded: downloaded_files/nam_218_2024030118.g2.tar
# Extracted: downloaded_files/nam_218_2024030118.g2.tar
# Deleted: downloaded_files/nam_218_2024030118.g2.tar
# downloaded_files/nam_218_2024030212.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024030212.g2.tar
# Downloaded: downloaded_files/nam_218_2024030212.g2.tar
# Extracted: downloaded_files/nam_218_2024030212.g2.tar
# Deleted: downloaded_files/nam_218_2024030212.g2.tar
# downloaded_files/nam_218_2024030218.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024030218.g2.tar
# Downloaded: downloaded_files/nam_218_2024030218.g2.tar
# Extracted: downloaded_files/nam_218_2024030218.g2.tar
# Deleted: downloaded_files/nam_218_2024030218.g2.tar
# downloaded_files/nam_218_2024030312.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024030312.g2.tar
# Downloaded: downloaded_files/nam_218_2024030312.g2.tar
# Extracted: downloaded_files/nam_218_2024030312.g2.tar
# Deleted: downloaded_files/nam_218_2024030312.g2.tar
# downloaded_files/nam_218_2024030318.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024030318.g2.tar
# Downloaded: downloaded_files/nam_218_2024030318.g2.tar
# Extracted: downloaded_files/nam_218_2024030318.g2.tar
# Deleted: downloaded_files/nam_218_2024030318.g2.tar
# downloaded_files/nam_218_2024030412.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024030412.g2.tar
# Downloaded: downloaded_files/nam_218_2024030412.g2.tar
# Extracted: downloaded_files/nam_218_2024030412.g2.tar
# Deleted: downloaded_files/nam_218_2024030412.g2.tar
# downloaded_files/nam_218_2024030418.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024030418.g2.tar
# Downloaded: downloaded_files/nam_218_2024030418.g2.tar
# Extracted: downloaded_files/nam_218_2024030418.g2.tar
# Deleted: downloaded_files/nam_218_2024030418.g2.tar
# downloaded_files/nam_218_2024030512.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024030512.g2.tar
# Downloaded: downloaded_files/nam_218_2024030512.g2.tar
# Extracted: downloaded_files/nam_218_2024030512.g2.tar
# Deleted: downloaded_files/nam_218_2024030512.g2.tar
# downloaded_files/nam_218_2024030518.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024030518.g2.tar
# Downloaded: downloaded_files/nam_218_2024030518.g2.tar
# Extracted: downloaded_files/nam_218_2024030518.g2.tar
# Deleted: downloaded_files/nam_218_2024030518.g2.tar
# downloaded_files/nam_218_2024030612.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024030612.g2.tar
# Downloaded: downloaded_files/nam_218_2024030612.g2.tar
# Extracted: downloaded_files/nam_218_2024030612.g2.tar
# Deleted: downloaded_files/nam_218_2024030612.g2.tar
# downloaded_files/nam_218_2024030618.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024030618.g2.tar
# Downloaded: downloaded_files/nam_218_2024030618.g2.tar
# Extracted: downloaded_files/nam_218_2024030618.g2.tar
# Deleted: downloaded_files/nam_218_2024030618.g2.tar
# downloaded_files/nam_218_2024030712.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024030712.g2.tar
# Downloaded: downloaded_files/nam_218_2024030712.g2.tar
# Extracted: downloaded_files/nam_218_2024030712.g2.tar
# Deleted: downloaded_files/nam_218_2024030712.g2.tar
# downloaded_files/nam_218_2024030718.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024030718.g2.tar
# Downloaded: downloaded_files/nam_218_2024030718.g2.tar
# Extracted: downloaded_files/nam_218_2024030718.g2.tar
# Deleted: downloaded_files/nam_218_2024030718.g2.tar
# downloaded_files/nam_218_2024030812.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024030812.g2.tar
# Downloaded: downloaded_files/nam_218_2024030812.g2.tar
# Extracted: downloaded_files/nam_218_2024030812.g2.tar
# Deleted: downloaded_files/nam_218_2024030812.g2.tar
# downloaded_files/nam_218_2024030818.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024030818.g2.tar
# Downloaded: downloaded_files/nam_218_2024030818.g2.tar
# Extracted: downloaded_files/nam_218_2024030818.g2.tar
# Deleted: downloaded_files/nam_218_2024030818.g2.tar
# downloaded_files/nam_218_2024030912.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024030912.g2.tar
# Downloaded: downloaded_files/nam_218_2024030912.g2.tar
# Extracted: downloaded_files/nam_218_2024030912.g2.tar
# Deleted: downloaded_files/nam_218_2024030912.g2.tar
# downloaded_files/nam_218_2024030918.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024030918.g2.tar
# Downloaded: downloaded_files/nam_218_2024030918.g2.tar
# Extracted: downloaded_files/nam_218_2024030918.g2.tar
# Deleted: downloaded_files/nam_218_2024030918.g2.tar
# downloaded_files/nam_218_2024031012.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024031012.g2.tar
# Downloaded: downloaded_files/nam_218_2024031012.g2.tar
# Extracted: downloaded_files/nam_218_2024031012.g2.tar
# Deleted: downloaded_files/nam_218_2024031012.g2.tar
# downloaded_files/nam_218_2024031018.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024031018.g2.tar
# Downloaded: downloaded_files/nam_218_2024031018.g2.tar
# Extracted: downloaded_files/nam_218_2024031018.g2.tar
# Deleted: downloaded_files/nam_218_2024031018.g2.tar
# downloaded_files/nam_218_2024031112.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024031112.g2.tar
# Downloaded: downloaded_files/nam_218_2024031112.g2.tar
# Extracted: downloaded_files/nam_218_2024031112.g2.tar
# Deleted: downloaded_files/nam_218_2024031112.g2.tar
# downloaded_files/nam_218_2024031118.g2.tar
# Downloading https://www.ncei.noaa.gov/pub/has/model/HAS012561864/nam_218_2024031118.g2.tar
# Downloaded: downloaded_files/nam_218_2024031118.g2.tar
# Extracted: downloaded_files/nam_218_2024031118.g2.tar
# Deleted: downloaded_files/nam_218_2024031118.g2.tar

# %% [markdown]
# # Next, extract the needed values (wind speed, wind direction, temp, kinetic energy, etc)

# %%
# Coordinates of anemometer
location_lat = 47.8437031
location_lon = -102.8524607

# %%
# Investigate how to dig into NAM data

# Confirm that unit of wind components is m/s and boundary layer level 0 (100-1000 m off ground)
grbs = pygrib.open('nam_files/nam_218_2024020806.g2/nam_218_20240208_0600_002.grb2')

# These are the desired data 
u_grb = grbs.select(name='U component of wind', level=0)[0]  # Select U component
v_grb = grbs.select(name='V component of wind', level=0)[0]  # Select V component
vert_vel_grb = grbs.select(name='Geometric vertical velocity', level=925)[0]  # 100000 Pa = about ground level
temp_K = grbs.select(name='Temperature', level=0)[0] # temp surface level, in K
kinetic_e = grbs.select(name='Turbulent kinetic energy', level=925)[0] # Turbulent kinetic energy:J kg**-1

print(u_grb)
print(v_grb)
print(vert_vel_grb)
print(temp_K)
print(kinetic_e)

for grb in grbs:
   #print(grb)
   if (grb.name == "Turbulent kinetic energy"):
        print(grb)
        print(grb.values[0][0])

grbs.close()
# Out:
# 8:U component of wind:m s**-1 (instant):lambert:planetaryBoundaryLayer:level 0:fcst time 2 hrs:from 202402080600
# 9:V component of wind:m s**-1 (instant):lambert:planetaryBoundaryLayer:level 0:fcst time 2 hrs:from 202402080600
# 304:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 92500 Pa:fcst time 2 hrs:from 202402080600
# 339:Temperature:K (instant):lambert:surface:level 0:fcst time 2 hrs:from 202402080600
# 307:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 92500 Pa:fcst time 2 hrs:from 202402080600
# 23:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 2 hrs:from 202402080600
# 0.020000000330000007
# 31:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 7500 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995422363283
# 39:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995422363283
# 47:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 2 hrs:from 202402080600
# 0.019999996185302734
# 55:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 15000 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 63:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 17500 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 71:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 20000 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 79:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 22500 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 88:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 96:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 27500 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 104:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 112:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 32500 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 120:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 35000 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 128:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 37500 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 136:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 40000 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 144:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 42500 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 152:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 45000 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 160:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 47500 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 169:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 50000 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 177:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 52500 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 185:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 55000 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 193:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 57500 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 201:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 60000 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 209:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 62500 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 217:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 65000 Pa:fcst time 2 hrs:from 202402080600
# 0.019999995231628417
# 225:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 67500 Pa:fcst time 2 hrs:from 202402080600
# 0.0
# 234:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 70000 Pa:fcst time 2 hrs:from 202402080600
# 0.0
# 242:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 72500 Pa:fcst time 2 hrs:from 202402080600
# 0.0
# 250:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 75000 Pa:fcst time 2 hrs:from 202402080600
# 0.0
# 258:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 77500 Pa:fcst time 2 hrs:from 202402080600
# 0.0
# 266:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 80000 Pa:fcst time 2 hrs:from 202402080600
# 0.0
# 274:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 82500 Pa:fcst time 2 hrs:from 202402080600
# 0.0
# 283:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 85000 Pa:fcst time 2 hrs:from 202402080600
# 0.0
# 291:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 87500 Pa:fcst time 2 hrs:from 202402080600
# 0.0
# 299:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 90000 Pa:fcst time 2 hrs:from 202402080600
# 0.0
# 307:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 92500 Pa:fcst time 2 hrs:from 202402080600
# 0.0
# 315:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 95000 Pa:fcst time 2 hrs:from 202402080600
# 0.5
# 324:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 97500 Pa:fcst time 2 hrs:from 202402080600
# 0.8
# 332:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 100000 Pa:fcst time 2 hrs:from 202402080600
# 1.0

# %%
# Define function to read in file and compute wind speed and direction closest to an input lat and long

def get_wind(filename, lat, lon):
    
    # open file
    grbs = pygrib.open(filename)

    # Extract U and V components, and wind speed
    u_grb = grbs.select(name='U component of wind', level=80)[0]  # Select U component, 80m above ground
    v_grb = grbs.select(name='V component of wind', level=80)[0]  # Select V component, 80m above ground
    vert_vel_grb = grbs.select(name='Geometric vertical velocity', level=925)[0]  # 100000 Pa about ground level
    temp_K = grbs.select(name='Temperature', level=0)[0] # temp surface level, in K
    kinetic_e = grbs.select(name='Turbulent kinetic energy', level=925)[0] # Turbulent kinetic energy:J kg**-1

    # Get data and lat/lon
    u_data = u_grb.values
    v_data = v_grb.values
    vert_vel_data = vert_vel_grb.values
    temp_data = temp_K.values
    kinetic_e_data = kinetic_e.values
    lats, lons = u_grb.latlons()

    # Find the closest grid point
    from scipy.spatial import cKDTree
    tree = cKDTree(list(zip(lats.flatten(), lons.flatten())))
    dist, index = tree.query((lat, lon))

    # Get the u and v components at the closest grid point
    u_value = u_data.flatten()[index] # U Component: Represents wind speed in the east-west direction (positive values indicate winds from west).
    v_value = v_data.flatten()[index] # V Component: Represents wind speed in the north-south direction (positive values winds from south).
    vert_vel_value = vert_vel_data.flatten()[index] # Represents vetical component of wind speed
    temp_value = temp_data.flatten()[index] - 273.15 # temp in Celcius
    kinetic_e_value = kinetic_e_data.flatten()[index]

    # Calculate horizontal wind speed at the closest grid point
    wind_speed_value = np.sqrt(u_value**2 + v_value**2)

    welv_value = np.arctan(vert_vel_value/wind_speed_value) * 180 / np.pi

    # Calculate wind direction
    # Calculation: The wind direction is calculated using the arctan2 function which provides the angle in radians. Convert this angle to degrees and adjust it to the 0-360 degree range.
    # Result: The result is the wind direction in degrees where 0° represents wind coming from the north, 90° from the east, 180° from the south, and 270° from the west.
    wind_direction = (np.arctan2(-u_value, -v_value) * 180 / np.pi) % 360

    datetime_str = filename[40:48]+filename[49:53]
    datetime_obj = datetime.strptime(datetime_str, '%Y%m%d%H%M')
    datetime_obj = pd.to_datetime(datetime_obj)
    forecast_str = filename[54:57]

    grbs.close()

    return datetime_obj, forecast_str, wind_speed_value, wind_direction, welv_value, temp_value, kinetic_e_value  # utc time, m/s, and degrees

# Try it out
get_wind('nam_files/nam_218_2024020806.g2/nam_218_20240208_0600_002.grb2', location_lat, location_lon )
# Out:
# (Timestamp('2024-02-08 06:00:00'),
#  '002',
#  6.2837645855587185,
#  330.3254928993131,
#  -0.06953458131239801,
#  -1.0156054687499818,
#  1.2000000000000002)

# %%
# Check that wind direction calculation works as expected
u = -1
v = 0
wind_direction_demo = (np.arctan2(u,v) * 180 / np.pi) % 360
wind_direction_demo
# Out:
# 270.0

# %%
# Loop through NAM data and get desired data

# Define the directory path and folders inside
directory_path = 'nam_files'  # change this to 'extracted_files' if the files are downloaded using the script (and add 6 to indices in for loop)
folder_names = sorted(os.listdir(directory_path)) 

# To save harddrive space and computation time, just keep these forecast periods
forecasts_to_keep = [0,1,2,3,4,6,12,24,48,72]

# Empty list to store wind data
nam_wind_data = []

# Loop through all files in the directory, and find wind data for each date
counter = 1
counter_data_added = 0
for folder_name in folder_names:
    if folder_name != '.DS_Store':
        # Create full path to the file
        folder_path = os.path.join(directory_path, folder_name)
        file_names = sorted(os.listdir(folder_path))
        for file_name in file_names: 
            if file_name != '.DS_Store':
                forecast = int(file_name[22:25])
                date = file_name[8:16]
                time = file_name[17:21]
                file_path = os.path.join(folder_path, file_name)
                if forecast not in forecasts_to_keep:
                    os.remove(file_path) # delete file permanently
                    print(f"{counter}: date {date}, time {time}, forecast period {forecast}: file deleted")
                else:
                    try:
                        nam_wind_data.append(get_wind(file_path, location_lat, location_lon )) 
                        print(f"{counter}: date {date}, time {time}, forecast period {forecast}: data added!")
                        counter_data_added+=1
                    except:
                        print(f"{counter}: date {date}, time {time}, forecast period {forecast}: no data found")
                counter+=1
print(f"Done! {counter_data_added} files successfully added.")
# Out:
# 1: date 20240208, time 0000, forecast period 0: data added!
# 2: date 20240208, time 0000, forecast period 1: data added!
# 3: date 20240208, time 0000, forecast period 2: data added!
# 4: date 20240208, time 0000, forecast period 3: data added!
# 5: date 20240208, time 0000, forecast period 4: data added!
# 6: date 20240208, time 0000, forecast period 6: data added!
# 7: date 20240208, time 0000, forecast period 12: data added!
# 8: date 20240208, time 0000, forecast period 24: data added!
# 9: date 20240208, time 0000, forecast period 48: data added!
# 10: date 20240208, time 0000, forecast period 72: data added!
# 11: date 20240208, time 0600, forecast period 0: data added!
# 12: date 20240208, time 0600, forecast period 1: data added!
# 13: date 20240208, time 0600, forecast period 2: data added!
# 14: date 20240208, time 0600, forecast period 3: data added!
# 15: date 20240208, time 0600, forecast period 4: data added!
# 16: date 20240208, time 0600, forecast period 6: data added!
# 17: date 20240208, time 0600, forecast period 12: data added!
# 18: date 20240208, time 0600, forecast period 24: data added!
# 19: date 20240208, time 0600, forecast period 48: data added!
# 20: date 20240208, time 0600, forecast period 72: data added!
# 21: date 20240208, time 1200, forecast period 0: data added!
# 22: date 20240208, time 1200, forecast period 1: data added!
# 23: date 20240208, time 1200, forecast period 2: data added!
# 24: date 20240208, time 1200, forecast period 3: data added!
# 25: date 20240208, time 1200, forecast period 4: data added!
# 26: date 20240208, time 1200, forecast period 6: data added!
# 27: date 20240208, time 1200, forecast period 12: data added!
# 28: date 20240208, time 1200, forecast period 24: data added!
# 29: date 20240208, time 1200, forecast period 48: data added!
# 30: date 20240208, time 1200, forecast period 72: data added!
# 31: date 20240208, time 1800, forecast period 0: data added!
# 32: date 20240208, time 1800, forecast period 1: data added!
# 33: date 20240208, time 1800, forecast period 2: data added!
# 34: date 20240208, time 1800, forecast period 3: data added!
# 35: date 20240208, time 1800, forecast period 4: data added!
# 36: date 20240208, time 1800, forecast period 6: data added!
# 37: date 20240208, time 1800, forecast period 12: data added!
# 38: date 20240208, time 1800, forecast period 24: data added!
# 39: date 20240208, time 1800, forecast period 48: data added!
# 40: date 20240208, time 1800, forecast period 72: data added!
# 41: date 20240209, time 0000, forecast period 0: data added!
# 42: date 20240209, time 0000, forecast period 1: data added!
# 43: date 20240209, time 0000, forecast period 2: data added!
# 44: date 20240209, time 0000, forecast period 3: data added!
# 45: date 20240209, time 0000, forecast period 4: data added!
# 46: date 20240209, time 0000, forecast period 6: data added!
# 47: date 20240209, time 0000, forecast period 12: data added!
# 48: date 20240209, time 0000, forecast period 24: data added!
# 49: date 20240209, time 0000, forecast period 48: data added!
# 50: date 20240209, time 0000, forecast period 72: data added!
# 51: date 20240209, time 0600, forecast period 0: data added!
# 52: date 20240209, time 0600, forecast period 1: data added!
# 53: date 20240209, time 0600, forecast period 2: data added!
# 54: date 20240209, time 0600, forecast period 3: data added!
# 55: date 20240209, time 0600, forecast period 4: data added!
# 56: date 20240209, time 0600, forecast period 6: data added!
# 57: date 20240209, time 0600, forecast period 12: data added!
# 58: date 20240209, time 0600, forecast period 24: data added!
# 59: date 20240209, time 0600, forecast period 48: data added!
# 60: date 20240209, time 0600, forecast period 72: data added!
# 61: date 20240209, time 1200, forecast period 0: data added!
# 62: date 20240209, time 1200, forecast period 1: data added!
# 63: date 20240209, time 1200, forecast period 2: data added!
# 64: date 20240209, time 1200, forecast period 3: data added!
# 65: date 20240209, time 1200, forecast period 4: data added!
# 66: date 20240209, time 1200, forecast period 6: data added!
# 67: date 20240209, time 1200, forecast period 12: data added!
# 68: date 20240209, time 1200, forecast period 24: data added!
# 69: date 20240209, time 1200, forecast period 48: data added!
# 70: date 20240209, time 1200, forecast period 72: data added!
# 71: date 20240209, time 1800, forecast period 0: data added!
# 72: date 20240209, time 1800, forecast period 1: data added!
# 73: date 20240209, time 1800, forecast period 2: data added!
# 74: date 20240209, time 1800, forecast period 3: data added!
# 75: date 20240209, time 1800, forecast period 4: data added!
# 76: date 20240209, time 1800, forecast period 6: data added!
# 77: date 20240209, time 1800, forecast period 12: data added!
# 78: date 20240209, time 1800, forecast period 24: data added!
# 79: date 20240209, time 1800, forecast period 48: data added!
# 80: date 20240209, time 1800, forecast period 72: data added!
# 81: date 20240210, time 0000, forecast period 0: data added!
# 82: date 20240210, time 0000, forecast period 1: data added!
# 83: date 20240210, time 0000, forecast period 2: data added!
# 84: date 20240210, time 0000, forecast period 3: data added!
# 85: date 20240210, time 0000, forecast period 4: data added!
# 86: date 20240210, time 0000, forecast period 6: data added!
# 87: date 20240210, time 0000, forecast period 12: data added!
# 88: date 20240210, time 0000, forecast period 24: data added!
# 89: date 20240210, time 0000, forecast period 48: data added!
# 90: date 20240210, time 0000, forecast period 72: data added!
# 91: date 20240210, time 0600, forecast period 0: data added!
# 92: date 20240210, time 0600, forecast period 1: data added!
# 93: date 20240210, time 0600, forecast period 2: no data found
# 94: date 20240210, time 0600, forecast period 3: data added!
# 95: date 20240210, time 0600, forecast period 4: data added!
# 96: date 20240210, time 0600, forecast period 6: data added!
# 97: date 20240210, time 0600, forecast period 12: data added!
# 98: date 20240210, time 0600, forecast period 24: data added!
# 99: date 20240210, time 0600, forecast period 48: data added!
# 100: date 20240210, time 0600, forecast period 72: data added!
# 101: date 20240210, time 1200, forecast period 0: data added!
# 102: date 20240210, time 1200, forecast period 1: data added!
# 103: date 20240210, time 1200, forecast period 2: data added!
# 104: date 20240210, time 1200, forecast period 3: data added!
# 105: date 20240210, time 1200, forecast period 4: data added!
# 106: date 20240210, time 1200, forecast period 6: data added!
# 107: date 20240210, time 1200, forecast period 12: data added!
# 108: date 20240210, time 1200, forecast period 24: data added!
# 109: date 20240210, time 1200, forecast period 48: data added!
# 110: date 20240210, time 1200, forecast period 72: data added!
# 111: date 20240210, time 1800, forecast period 0: data added!
# 112: date 20240210, time 1800, forecast period 1: data added!
# 113: date 20240210, time 1800, forecast period 2: data added!
# 114: date 20240210, time 1800, forecast period 3: data added!
# 115: date 20240210, time 1800, forecast period 4: data added!
# 116: date 20240210, time 1800, forecast period 6: data added!
# 117: date 20240210, time 1800, forecast period 12: data added!
# 118: date 20240210, time 1800, forecast period 24: data added!
# 119: date 20240210, time 1800, forecast period 48: data added!
# 120: date 20240210, time 1800, forecast period 72: data added!
# 121: date 20240211, time 0000, forecast period 0: data added!
# 122: date 20240211, time 0000, forecast period 1: data added!
# 123: date 20240211, time 0000, forecast period 2: data added!
# 124: date 20240211, time 0000, forecast period 3: data added!
# 125: date 20240211, time 0000, forecast period 4: data added!
# 126: date 20240211, time 0000, forecast period 6: data added!
# 127: date 20240211, time 0000, forecast period 12: data added!
# 128: date 20240211, time 0000, forecast period 24: data added!
# 129: date 20240211, time 0000, forecast period 48: data added!
# 130: date 20240211, time 0000, forecast period 72: data added!
# 131: date 20240211, time 0600, forecast period 0: data added!
# 132: date 20240211, time 0600, forecast period 1: data added!
# 133: date 20240211, time 0600, forecast period 2: data added!
# 134: date 20240211, time 0600, forecast period 3: data added!
# 135: date 20240211, time 0600, forecast period 4: data added!
# 136: date 20240211, time 0600, forecast period 6: data added!
# 137: date 20240211, time 0600, forecast period 12: data added!
# 138: date 20240211, time 0600, forecast period 24: data added!
# 139: date 20240211, time 0600, forecast period 48: data added!
# 140: date 20240211, time 0600, forecast period 72: data added!
# 141: date 20240211, time 1200, forecast period 0: data added!
# 142: date 20240211, time 1200, forecast period 1: data added!
# 143: date 20240211, time 1200, forecast period 2: data added!
# 144: date 20240211, time 1200, forecast period 3: data added!
# 145: date 20240211, time 1200, forecast period 4: data added!
# 146: date 20240211, time 1200, forecast period 6: data added!
# 147: date 20240211, time 1200, forecast period 12: data added!
# 148: date 20240211, time 1200, forecast period 24: data added!
# 149: date 20240211, time 1200, forecast period 48: data added!
# 150: date 20240211, time 1200, forecast period 72: data added!
# 151: date 20240211, time 1800, forecast period 0: data added!
# 152: date 20240211, time 1800, forecast period 1: data added!
# 153: date 20240211, time 1800, forecast period 2: data added!
# 154: date 20240211, time 1800, forecast period 3: data added!
# 155: date 20240211, time 1800, forecast period 4: data added!
# 156: date 20240211, time 1800, forecast period 6: data added!
# 157: date 20240211, time 1800, forecast period 12: data added!
# 158: date 20240211, time 1800, forecast period 24: data added!
# 159: date 20240211, time 1800, forecast period 48: data added!
# 160: date 20240211, time 1800, forecast period 72: data added!
# 161: date 20240212, time 0000, forecast period 0: data added!
# 162: date 20240212, time 0000, forecast period 1: data added!
# 163: date 20240212, time 0000, forecast period 2: data added!
# 164: date 20240212, time 0000, forecast period 3: data added!
# 165: date 20240212, time 0000, forecast period 4: data added!
# 166: date 20240212, time 0000, forecast period 6: data added!
# 167: date 20240212, time 0000, forecast period 12: data added!
# 168: date 20240212, time 0000, forecast period 24: data added!
# 169: date 20240212, time 0000, forecast period 48: data added!
# 170: date 20240212, time 0000, forecast period 72: data added!
# 171: date 20240212, time 0600, forecast period 0: data added!
# 172: date 20240212, time 0600, forecast period 1: data added!
# 173: date 20240212, time 0600, forecast period 2: data added!
# 174: date 20240212, time 0600, forecast period 3: data added!
# 175: date 20240212, time 0600, forecast period 4: data added!
# 176: date 20240212, time 0600, forecast period 6: data added!
# 177: date 20240212, time 0600, forecast period 12: data added!
# 178: date 20240212, time 0600, forecast period 24: data added!
# 179: date 20240212, time 0600, forecast period 48: data added!
# 180: date 20240212, time 0600, forecast period 72: data added!
# 181: date 20240212, time 1200, forecast period 0: data added!
# 182: date 20240212, time 1200, forecast period 1: data added!
# 183: date 20240212, time 1200, forecast period 2: data added!
# 184: date 20240212, time 1200, forecast period 3: data added!
# 185: date 20240212, time 1200, forecast period 4: data added!
# 186: date 20240212, time 1200, forecast period 6: data added!
# 187: date 20240212, time 1200, forecast period 12: data added!
# 188: date 20240212, time 1200, forecast period 24: data added!
# 189: date 20240212, time 1200, forecast period 48: data added!
# 190: date 20240212, time 1200, forecast period 72: data added!
# 191: date 20240212, time 1800, forecast period 0: data added!
# 192: date 20240212, time 1800, forecast period 1: data added!
# 193: date 20240212, time 1800, forecast period 2: data added!
# 194: date 20240212, time 1800, forecast period 3: data added!
# 195: date 20240212, time 1800, forecast period 4: data added!
# 196: date 20240212, time 1800, forecast period 6: data added!
# 197: date 20240212, time 1800, forecast period 12: data added!
# 198: date 20240212, time 1800, forecast period 24: data added!
# 199: date 20240212, time 1800, forecast period 48: data added!
# 200: date 20240212, time 1800, forecast period 72: data added!
# 201: date 20240213, time 0000, forecast period 0: data added!
# 202: date 20240213, time 0000, forecast period 1: data added!
# 203: date 20240213, time 0000, forecast period 2: data added!
# 204: date 20240213, time 0000, forecast period 3: data added!
# 205: date 20240213, time 0000, forecast period 4: data added!
# 206: date 20240213, time 0000, forecast period 6: data added!
# 207: date 20240213, time 0000, forecast period 12: data added!
# 208: date 20240213, time 0000, forecast period 24: data added!
# 209: date 20240213, time 0000, forecast period 48: data added!
# 210: date 20240213, time 0000, forecast period 72: data added!
# 211: date 20240213, time 0600, forecast period 0: data added!
# 212: date 20240213, time 0600, forecast period 1: data added!
# 213: date 20240213, time 0600, forecast period 2: data added!
# 214: date 20240213, time 0600, forecast period 3: data added!
# 215: date 20240213, time 0600, forecast period 4: data added!
# 216: date 20240213, time 0600, forecast period 6: data added!
# 217: date 20240213, time 0600, forecast period 12: data added!
# 218: date 20240213, time 0600, forecast period 24: data added!
# 219: date 20240213, time 0600, forecast period 48: data added!
# 220: date 20240213, time 0600, forecast period 72: data added!
# 221: date 20240213, time 1200, forecast period 0: data added!
# 222: date 20240213, time 1200, forecast period 1: data added!
# 223: date 20240213, time 1200, forecast period 2: data added!
# 224: date 20240213, time 1200, forecast period 3: data added!
# 225: date 20240213, time 1200, forecast period 4: data added!
# 226: date 20240213, time 1200, forecast period 6: data added!
# 227: date 20240213, time 1200, forecast period 12: data added!
# 228: date 20240213, time 1200, forecast period 24: data added!
# 229: date 20240213, time 1200, forecast period 48: data added!
# 230: date 20240213, time 1200, forecast period 72: data added!
# 231: date 20240213, time 1800, forecast period 0: data added!
# 232: date 20240213, time 1800, forecast period 1: data added!
# 233: date 20240213, time 1800, forecast period 2: data added!
# 234: date 20240213, time 1800, forecast period 3: data added!
# 235: date 20240213, time 1800, forecast period 4: data added!
# 236: date 20240213, time 1800, forecast period 6: data added!
# 237: date 20240213, time 1800, forecast period 12: data added!
# 238: date 20240213, time 1800, forecast period 24: data added!
# 239: date 20240213, time 1800, forecast period 48: data added!
# 240: date 20240213, time 1800, forecast period 72: data added!
# 241: date 20240214, time 0000, forecast period 0: data added!
# 242: date 20240214, time 0000, forecast period 1: data added!
# 243: date 20240214, time 0000, forecast period 2: data added!
# 244: date 20240214, time 0000, forecast period 3: data added!
# 245: date 20240214, time 0000, forecast period 4: data added!
# 246: date 20240214, time 0000, forecast period 6: data added!
# 247: date 20240214, time 0000, forecast period 12: data added!
# 248: date 20240214, time 0000, forecast period 24: data added!
# 249: date 20240214, time 0000, forecast period 48: data added!
# 250: date 20240214, time 0000, forecast period 72: data added!
# 251: date 20240214, time 0600, forecast period 0: data added!
# 252: date 20240214, time 0600, forecast period 1: data added!
# 253: date 20240214, time 0600, forecast period 2: data added!
# 254: date 20240214, time 0600, forecast period 3: data added!
# 255: date 20240214, time 0600, forecast period 4: data added!
# 256: date 20240214, time 0600, forecast period 6: data added!
# 257: date 20240214, time 0600, forecast period 12: data added!
# 258: date 20240214, time 0600, forecast period 24: data added!
# 259: date 20240214, time 0600, forecast period 48: data added!
# 260: date 20240214, time 0600, forecast period 72: data added!
# 261: date 20240214, time 1200, forecast period 0: data added!
# 262: date 20240214, time 1200, forecast period 1: data added!
# 263: date 20240214, time 1200, forecast period 2: data added!
# 264: date 20240214, time 1200, forecast period 3: data added!
# 265: date 20240214, time 1200, forecast period 4: data added!
# 266: date 20240214, time 1200, forecast period 6: data added!
# 267: date 20240214, time 1200, forecast period 12: data added!
# 268: date 20240214, time 1200, forecast period 24: data added!
# 269: date 20240214, time 1200, forecast period 48: data added!
# 270: date 20240214, time 1200, forecast period 72: data added!
# 271: date 20240214, time 1800, forecast period 0: data added!
# 272: date 20240214, time 1800, forecast period 1: data added!
# 273: date 20240214, time 1800, forecast period 2: data added!
# 274: date 20240214, time 1800, forecast period 3: data added!
# 275: date 20240214, time 1800, forecast period 4: data added!
# 276: date 20240214, time 1800, forecast period 6: data added!
# 277: date 20240214, time 1800, forecast period 12: data added!
# 278: date 20240214, time 1800, forecast period 24: data added!
# 279: date 20240214, time 1800, forecast period 48: data added!
# 280: date 20240214, time 1800, forecast period 72: data added!
# 281: date 20240215, time 0000, forecast period 0: data added!
# 282: date 20240215, time 0000, forecast period 1: data added!
# 283: date 20240215, time 0000, forecast period 2: data added!
# 284: date 20240215, time 0000, forecast period 3: data added!
# 285: date 20240215, time 0000, forecast period 4: data added!
# 286: date 20240215, time 0000, forecast period 6: data added!
# 287: date 20240215, time 0000, forecast period 12: data added!
# 288: date 20240215, time 0000, forecast period 24: data added!
# 289: date 20240215, time 0000, forecast period 48: data added!
# 290: date 20240215, time 0000, forecast period 72: data added!
# 291: date 20240215, time 0600, forecast period 0: data added!
# 292: date 20240215, time 0600, forecast period 1: data added!
# 293: date 20240215, time 0600, forecast period 2: data added!
# 294: date 20240215, time 0600, forecast period 3: data added!
# 295: date 20240215, time 0600, forecast period 4: data added!
# 296: date 20240215, time 0600, forecast period 6: data added!
# 297: date 20240215, time 0600, forecast period 12: data added!
# 298: date 20240215, time 0600, forecast period 24: data added!
# 299: date 20240215, time 0600, forecast period 48: data added!
# 300: date 20240215, time 0600, forecast period 72: data added!
# 301: date 20240215, time 1200, forecast period 0: data added!
# 302: date 20240215, time 1200, forecast period 1: data added!
# 303: date 20240215, time 1200, forecast period 2: data added!
# 304: date 20240215, time 1200, forecast period 3: data added!
# 305: date 20240215, time 1200, forecast period 4: data added!
# 306: date 20240215, time 1200, forecast period 6: data added!
# 307: date 20240215, time 1200, forecast period 12: data added!
# 308: date 20240215, time 1200, forecast period 24: data added!
# 309: date 20240215, time 1200, forecast period 48: data added!
# 310: date 20240215, time 1200, forecast period 72: data added!
# 311: date 20240215, time 1800, forecast period 0: data added!
# 312: date 20240215, time 1800, forecast period 1: data added!
# 313: date 20240215, time 1800, forecast period 2: data added!
# 314: date 20240215, time 1800, forecast period 3: data added!
# 315: date 20240215, time 1800, forecast period 4: data added!
# 316: date 20240215, time 1800, forecast period 6: data added!
# 317: date 20240215, time 1800, forecast period 12: data added!
# 318: date 20240215, time 1800, forecast period 24: data added!
# 319: date 20240215, time 1800, forecast period 48: data added!
# 320: date 20240215, time 1800, forecast period 72: data added!
# 321: date 20240216, time 0000, forecast period 0: data added!
# 322: date 20240216, time 0000, forecast period 1: data added!
# 323: date 20240216, time 0000, forecast period 2: data added!
# 324: date 20240216, time 0000, forecast period 3: data added!
# 325: date 20240216, time 0000, forecast period 4: data added!
# 326: date 20240216, time 0000, forecast period 6: data added!
# 327: date 20240216, time 0000, forecast period 12: data added!
# 328: date 20240216, time 0000, forecast period 24: data added!
# 329: date 20240216, time 0000, forecast period 48: data added!
# 330: date 20240216, time 0000, forecast period 72: data added!
# 331: date 20240216, time 0600, forecast period 0: data added!
# 332: date 20240216, time 0600, forecast period 1: data added!
# 333: date 20240216, time 0600, forecast period 2: data added!
# 334: date 20240216, time 0600, forecast period 3: data added!
# 335: date 20240216, time 0600, forecast period 4: data added!
# 336: date 20240216, time 0600, forecast period 6: data added!
# 337: date 20240216, time 0600, forecast period 12: data added!
# 338: date 20240216, time 0600, forecast period 24: data added!
# 339: date 20240216, time 0600, forecast period 48: data added!
# 340: date 20240216, time 0600, forecast period 72: data added!
# 341: date 20240216, time 1200, forecast period 0: data added!
# 342: date 20240216, time 1200, forecast period 1: data added!
# 343: date 20240216, time 1200, forecast period 2: data added!
# 344: date 20240216, time 1200, forecast period 3: data added!
# 345: date 20240216, time 1200, forecast period 4: data added!
# 346: date 20240216, time 1200, forecast period 6: data added!
# 347: date 20240216, time 1200, forecast period 12: data added!
# 348: date 20240216, time 1200, forecast period 24: data added!
# 349: date 20240216, time 1200, forecast period 48: data added!
# 350: date 20240216, time 1200, forecast period 72: data added!
# 351: date 20240216, time 1800, forecast period 0: data added!
# 352: date 20240216, time 1800, forecast period 1: data added!
# 353: date 20240216, time 1800, forecast period 2: data added!
# 354: date 20240216, time 1800, forecast period 3: data added!
# 355: date 20240216, time 1800, forecast period 4: data added!
# 356: date 20240216, time 1800, forecast period 6: data added!
# 357: date 20240216, time 1800, forecast period 12: data added!
# 358: date 20240216, time 1800, forecast period 24: data added!
# 359: date 20240216, time 1800, forecast period 48: data added!
# 360: date 20240216, time 1800, forecast period 72: data added!
# 361: date 20240217, time 0000, forecast period 0: data added!
# 362: date 20240217, time 0000, forecast period 1: data added!
# 363: date 20240217, time 0000, forecast period 2: data added!
# 364: date 20240217, time 0000, forecast period 3: data added!
# 365: date 20240217, time 0000, forecast period 4: data added!
# 366: date 20240217, time 0000, forecast period 6: data added!
# 367: date 20240217, time 0000, forecast period 12: data added!
# 368: date 20240217, time 0000, forecast period 24: data added!
# 369: date 20240217, time 0000, forecast period 48: data added!
# 370: date 20240217, time 0000, forecast period 72: data added!
# 371: date 20240217, time 0600, forecast period 0: data added!
# 372: date 20240217, time 0600, forecast period 1: data added!
# 373: date 20240217, time 0600, forecast period 2: data added!
# 374: date 20240217, time 0600, forecast period 3: data added!
# 375: date 20240217, time 0600, forecast period 4: data added!
# 376: date 20240217, time 0600, forecast period 6: data added!
# 377: date 20240217, time 0600, forecast period 12: data added!
# 378: date 20240217, time 0600, forecast period 24: data added!
# 379: date 20240217, time 0600, forecast period 48: data added!
# 380: date 20240217, time 0600, forecast period 72: data added!
# 381: date 20240217, time 1200, forecast period 0: data added!
# 382: date 20240217, time 1200, forecast period 1: data added!
# 383: date 20240217, time 1200, forecast period 2: data added!
# 384: date 20240217, time 1200, forecast period 3: data added!
# 385: date 20240217, time 1200, forecast period 4: data added!
# 386: date 20240217, time 1200, forecast period 6: data added!
# 387: date 20240217, time 1200, forecast period 12: data added!
# 388: date 20240217, time 1200, forecast period 24: data added!
# 389: date 20240217, time 1200, forecast period 48: data added!
# 390: date 20240217, time 1200, forecast period 72: data added!
# 391: date 20240217, time 1800, forecast period 0: data added!
# 392: date 20240217, time 1800, forecast period 1: data added!
# 393: date 20240217, time 1800, forecast period 2: data added!
# 394: date 20240217, time 1800, forecast period 3: data added!
# 395: date 20240217, time 1800, forecast period 4: data added!
# 396: date 20240217, time 1800, forecast period 6: data added!
# 397: date 20240217, time 1800, forecast period 12: data added!
# 398: date 20240217, time 1800, forecast period 24: data added!
# 399: date 20240217, time 1800, forecast period 48: data added!
# 400: date 20240217, time 1800, forecast period 72: data added!
# 401: date 20240218, time 0000, forecast period 0: data added!
# 402: date 20240218, time 0000, forecast period 1: data added!
# 403: date 20240218, time 0000, forecast period 2: data added!
# 404: date 20240218, time 0000, forecast period 3: data added!
# 405: date 20240218, time 0000, forecast period 4: data added!
# 406: date 20240218, time 0000, forecast period 6: data added!
# 407: date 20240218, time 0000, forecast period 12: data added!
# 408: date 20240218, time 0000, forecast period 24: data added!
# 409: date 20240218, time 0000, forecast period 48: data added!
# 410: date 20240218, time 0000, forecast period 72: data added!
# 411: date 20240218, time 0600, forecast period 0: data added!
# 412: date 20240218, time 0600, forecast period 1: data added!
# 413: date 20240218, time 0600, forecast period 2: data added!
# 414: date 20240218, time 0600, forecast period 3: data added!
# 415: date 20240218, time 0600, forecast period 4: data added!
# 416: date 20240218, time 0600, forecast period 6: data added!
# 417: date 20240218, time 0600, forecast period 12: data added!
# 418: date 20240218, time 0600, forecast period 24: data added!
# 419: date 20240218, time 0600, forecast period 48: data added!
# 420: date 20240218, time 0600, forecast period 72: data added!
# 421: date 20240218, time 1200, forecast period 0: data added!
# 422: date 20240218, time 1200, forecast period 1: data added!
# 423: date 20240218, time 1200, forecast period 2: data added!
# 424: date 20240218, time 1200, forecast period 3: data added!
# 425: date 20240218, time 1200, forecast period 4: data added!
# 426: date 20240218, time 1200, forecast period 6: data added!
# 427: date 20240218, time 1200, forecast period 12: data added!
# 428: date 20240218, time 1200, forecast period 24: data added!
# 429: date 20240218, time 1200, forecast period 48: data added!
# 430: date 20240218, time 1200, forecast period 72: data added!
# 431: date 20240218, time 1800, forecast period 0: data added!
# 432: date 20240218, time 1800, forecast period 1: data added!
# 433: date 20240218, time 1800, forecast period 2: data added!
# 434: date 20240218, time 1800, forecast period 3: data added!
# 435: date 20240218, time 1800, forecast period 4: data added!
# 436: date 20240218, time 1800, forecast period 6: data added!
# 437: date 20240218, time 1800, forecast period 12: data added!
# 438: date 20240218, time 1800, forecast period 24: data added!
# 439: date 20240218, time 1800, forecast period 48: data added!
# 440: date 20240218, time 1800, forecast period 72: data added!
# 441: date 20240219, time 0000, forecast period 0: data added!
# 442: date 20240219, time 0000, forecast period 1: data added!
# 443: date 20240219, time 0000, forecast period 2: data added!
# 444: date 20240219, time 0000, forecast period 3: data added!
# 445: date 20240219, time 0000, forecast period 4: data added!
# 446: date 20240219, time 0000, forecast period 6: data added!
# 447: date 20240219, time 0000, forecast period 12: data added!
# 448: date 20240219, time 0000, forecast period 24: data added!
# 449: date 20240219, time 0000, forecast period 48: data added!
# 450: date 20240219, time 0000, forecast period 72: data added!
# 451: date 20240219, time 0600, forecast period 0: data added!
# 452: date 20240219, time 0600, forecast period 1: data added!
# 453: date 20240219, time 0600, forecast period 2: data added!
# 454: date 20240219, time 0600, forecast period 3: data added!
# 455: date 20240219, time 0600, forecast period 4: data added!
# 456: date 20240219, time 0600, forecast period 6: data added!
# 457: date 20240219, time 0600, forecast period 12: data added!
# 458: date 20240219, time 0600, forecast period 24: data added!
# 459: date 20240219, time 0600, forecast period 48: data added!
# 460: date 20240219, time 0600, forecast period 72: data added!
# 461: date 20240219, time 1200, forecast period 0: data added!
# 462: date 20240219, time 1200, forecast period 1: data added!
# 463: date 20240219, time 1200, forecast period 2: data added!
# 464: date 20240219, time 1200, forecast period 3: data added!
# 465: date 20240219, time 1200, forecast period 4: data added!
# 466: date 20240219, time 1200, forecast period 6: data added!
# 467: date 20240219, time 1200, forecast period 12: data added!
# 468: date 20240219, time 1200, forecast period 24: data added!
# 469: date 20240219, time 1200, forecast period 48: data added!
# 470: date 20240219, time 1200, forecast period 72: data added!
# 471: date 20240219, time 1800, forecast period 0: data added!
# 472: date 20240219, time 1800, forecast period 1: data added!
# 473: date 20240219, time 1800, forecast period 2: data added!
# 474: date 20240219, time 1800, forecast period 3: data added!
# 475: date 20240219, time 1800, forecast period 4: data added!
# 476: date 20240219, time 1800, forecast period 6: data added!
# 477: date 20240219, time 1800, forecast period 12: data added!
# 478: date 20240219, time 1800, forecast period 24: data added!
# 479: date 20240219, time 1800, forecast period 48: data added!
# 480: date 20240219, time 1800, forecast period 72: data added!
# 481: date 20240220, time 0000, forecast period 0: data added!
# 482: date 20240220, time 0000, forecast period 1: data added!
# 483: date 20240220, time 0000, forecast period 2: data added!
# 484: date 20240220, time 0000, forecast period 3: data added!
# 485: date 20240220, time 0000, forecast period 4: data added!
# 486: date 20240220, time 0000, forecast period 6: data added!
# 487: date 20240220, time 0000, forecast period 12: data added!
# 488: date 20240220, time 0000, forecast period 24: data added!
# 489: date 20240220, time 0000, forecast period 48: data added!
# 490: date 20240220, time 0000, forecast period 72: data added!
# 491: date 20240220, time 0600, forecast period 0: data added!
# 492: date 20240220, time 0600, forecast period 1: data added!
# 493: date 20240220, time 0600, forecast period 2: data added!
# 494: date 20240220, time 0600, forecast period 3: data added!
# 495: date 20240220, time 0600, forecast period 4: data added!
# 496: date 20240220, time 0600, forecast period 6: data added!
# 497: date 20240220, time 0600, forecast period 12: data added!
# 498: date 20240220, time 0600, forecast period 24: data added!
# 499: date 20240220, time 0600, forecast period 48: data added!
# 500: date 20240220, time 0600, forecast period 72: data added!
# 501: date 20240220, time 1200, forecast period 0: data added!
# 502: date 20240220, time 1200, forecast period 1: data added!
# 503: date 20240220, time 1200, forecast period 2: data added!
# 504: date 20240220, time 1200, forecast period 3: data added!
# 505: date 20240220, time 1200, forecast period 4: data added!
# 506: date 20240220, time 1200, forecast period 6: data added!
# 507: date 20240220, time 1200, forecast period 12: data added!
# 508: date 20240220, time 1200, forecast period 24: data added!
# 509: date 20240220, time 1200, forecast period 48: data added!
# 510: date 20240220, time 1200, forecast period 72: data added!
# 511: date 20240220, time 1800, forecast period 0: data added!
# 512: date 20240220, time 1800, forecast period 1: data added!
# 513: date 20240220, time 1800, forecast period 2: data added!
# 514: date 20240220, time 1800, forecast period 3: data added!
# 515: date 20240220, time 1800, forecast period 4: data added!
# 516: date 20240220, time 1800, forecast period 6: data added!
# 517: date 20240220, time 1800, forecast period 12: data added!
# 518: date 20240220, time 1800, forecast period 24: data added!
# 519: date 20240220, time 1800, forecast period 48: data added!
# 520: date 20240220, time 1800, forecast period 72: data added!
# 521: date 20240221, time 0000, forecast period 0: data added!
# 522: date 20240221, time 0000, forecast period 1: data added!
# 523: date 20240221, time 0000, forecast period 2: data added!
# 524: date 20240221, time 0000, forecast period 3: data added!
# 525: date 20240221, time 0000, forecast period 4: data added!
# 526: date 20240221, time 0000, forecast period 6: data added!
# 527: date 20240221, time 0000, forecast period 12: data added!
# 528: date 20240221, time 0000, forecast period 24: data added!
# 529: date 20240221, time 0000, forecast period 48: data added!
# 530: date 20240221, time 0000, forecast period 72: data added!
# 531: date 20240221, time 0600, forecast period 0: data added!
# 532: date 20240221, time 0600, forecast period 1: data added!
# 533: date 20240221, time 0600, forecast period 2: data added!
# 534: date 20240221, time 0600, forecast period 3: data added!
# 535: date 20240221, time 0600, forecast period 4: data added!
# 536: date 20240221, time 0600, forecast period 6: data added!
# 537: date 20240221, time 0600, forecast period 12: data added!
# 538: date 20240221, time 0600, forecast period 24: data added!
# 539: date 20240221, time 0600, forecast period 48: data added!
# 540: date 20240221, time 0600, forecast period 72: data added!
# 541: date 20240221, time 1200, forecast period 0: data added!
# 542: date 20240221, time 1200, forecast period 1: data added!
# 543: date 20240221, time 1200, forecast period 2: data added!
# 544: date 20240221, time 1200, forecast period 3: data added!
# 545: date 20240221, time 1200, forecast period 4: data added!
# 546: date 20240221, time 1200, forecast period 6: data added!
# 547: date 20240221, time 1200, forecast period 12: data added!
# 548: date 20240221, time 1200, forecast period 24: data added!
# 549: date 20240221, time 1200, forecast period 48: data added!
# 550: date 20240221, time 1200, forecast period 72: data added!
# 551: date 20240221, time 1800, forecast period 0: data added!
# 552: date 20240221, time 1800, forecast period 1: data added!
# 553: date 20240221, time 1800, forecast period 2: data added!
# 554: date 20240221, time 1800, forecast period 3: data added!
# 555: date 20240221, time 1800, forecast period 4: data added!
# 556: date 20240221, time 1800, forecast period 6: data added!
# 557: date 20240221, time 1800, forecast period 12: data added!
# 558: date 20240221, time 1800, forecast period 24: data added!
# 559: date 20240221, time 1800, forecast period 48: data added!
# 560: date 20240221, time 1800, forecast period 72: data added!
# 561: date 20240222, time 0000, forecast period 0: data added!
# 562: date 20240222, time 0000, forecast period 1: data added!
# 563: date 20240222, time 0000, forecast period 2: data added!
# 564: date 20240222, time 0000, forecast period 3: data added!
# 565: date 20240222, time 0000, forecast period 4: data added!
# 566: date 20240222, time 0000, forecast period 6: data added!
# 567: date 20240222, time 0000, forecast period 12: data added!
# 568: date 20240222, time 0000, forecast period 24: data added!
# 569: date 20240222, time 0000, forecast period 48: data added!
# 570: date 20240222, time 0000, forecast period 72: data added!
# 571: date 20240222, time 0600, forecast period 0: data added!
# 572: date 20240222, time 0600, forecast period 1: data added!
# 573: date 20240222, time 0600, forecast period 2: data added!
# 574: date 20240222, time 0600, forecast period 3: data added!
# 575: date 20240222, time 0600, forecast period 4: data added!
# 576: date 20240222, time 0600, forecast period 6: data added!
# 577: date 20240222, time 0600, forecast period 12: data added!
# 578: date 20240222, time 0600, forecast period 24: data added!
# 579: date 20240222, time 0600, forecast period 48: data added!
# 580: date 20240222, time 0600, forecast period 72: data added!
# 581: date 20240222, time 1200, forecast period 0: data added!
# 582: date 20240222, time 1200, forecast period 1: data added!
# 583: date 20240222, time 1200, forecast period 2: data added!
# 584: date 20240222, time 1200, forecast period 3: data added!
# 585: date 20240222, time 1200, forecast period 4: data added!
# 586: date 20240222, time 1200, forecast period 6: data added!
# 587: date 20240222, time 1200, forecast period 12: data added!
# 588: date 20240222, time 1200, forecast period 24: data added!
# 589: date 20240222, time 1200, forecast period 48: data added!
# 590: date 20240222, time 1200, forecast period 72: data added!
# 591: date 20240222, time 1800, forecast period 0: data added!
# 592: date 20240222, time 1800, forecast period 1: data added!
# 593: date 20240222, time 1800, forecast period 2: data added!
# 594: date 20240222, time 1800, forecast period 3: data added!
# 595: date 20240222, time 1800, forecast period 4: data added!
# 596: date 20240222, time 1800, forecast period 6: data added!
# 597: date 20240222, time 1800, forecast period 12: data added!
# 598: date 20240222, time 1800, forecast period 24: data added!
# 599: date 20240222, time 1800, forecast period 48: data added!
# 600: date 20240222, time 1800, forecast period 72: data added!
# 601: date 20240223, time 0000, forecast period 0: data added!
# 602: date 20240223, time 0000, forecast period 1: data added!
# 603: date 20240223, time 0000, forecast period 2: data added!
# 604: date 20240223, time 0000, forecast period 3: data added!
# 605: date 20240223, time 0000, forecast period 4: data added!
# 606: date 20240223, time 0000, forecast period 6: data added!
# 607: date 20240223, time 0000, forecast period 12: data added!
# 608: date 20240223, time 0000, forecast period 24: data added!
# 609: date 20240223, time 0000, forecast period 48: data added!
# 610: date 20240223, time 0000, forecast period 72: data added!
# 611: date 20240223, time 0600, forecast period 0: data added!
# 612: date 20240223, time 0600, forecast period 1: data added!
# 613: date 20240223, time 0600, forecast period 2: data added!
# 614: date 20240223, time 0600, forecast period 3: data added!
# 615: date 20240223, time 0600, forecast period 4: data added!
# 616: date 20240223, time 0600, forecast period 6: data added!
# 617: date 20240223, time 0600, forecast period 12: data added!
# 618: date 20240223, time 0600, forecast period 24: data added!
# 619: date 20240223, time 0600, forecast period 48: data added!
# 620: date 20240223, time 0600, forecast period 72: data added!
# 621: date 20240223, time 1200, forecast period 0: data added!
# 622: date 20240223, time 1200, forecast period 1: data added!
# 623: date 20240223, time 1200, forecast period 2: data added!
# 624: date 20240223, time 1200, forecast period 3: data added!
# 625: date 20240223, time 1200, forecast period 4: data added!
# 626: date 20240223, time 1200, forecast period 6: data added!
# 627: date 20240223, time 1200, forecast period 12: data added!
# 628: date 20240223, time 1200, forecast period 24: data added!
# 629: date 20240223, time 1200, forecast period 48: data added!
# 630: date 20240223, time 1200, forecast period 72: data added!
# 631: date 20240223, time 1800, forecast period 0: data added!
# 632: date 20240223, time 1800, forecast period 1: data added!
# 633: date 20240223, time 1800, forecast period 2: data added!
# 634: date 20240223, time 1800, forecast period 3: data added!
# 635: date 20240223, time 1800, forecast period 4: data added!
# 636: date 20240223, time 1800, forecast period 6: data added!
# 637: date 20240223, time 1800, forecast period 12: data added!
# 638: date 20240223, time 1800, forecast period 24: data added!
# 639: date 20240223, time 1800, forecast period 48: data added!
# 640: date 20240223, time 1800, forecast period 72: data added!
# 641: date 20240224, time 0000, forecast period 0: data added!
# 642: date 20240224, time 0000, forecast period 1: data added!
# 643: date 20240224, time 0000, forecast period 2: data added!
# 644: date 20240224, time 0000, forecast period 3: data added!
# 645: date 20240224, time 0000, forecast period 4: data added!
# 646: date 20240224, time 0000, forecast period 6: data added!
# 647: date 20240224, time 0000, forecast period 12: data added!
# 648: date 20240224, time 0000, forecast period 24: data added!
# 649: date 20240224, time 0000, forecast period 48: data added!
# 650: date 20240224, time 0000, forecast period 72: data added!
# 651: date 20240224, time 0600, forecast period 0: data added!
# 652: date 20240224, time 0600, forecast period 1: data added!
# 653: date 20240224, time 0600, forecast period 2: data added!
# 654: date 20240224, time 0600, forecast period 3: data added!
# 655: date 20240224, time 0600, forecast period 4: data added!
# 656: date 20240224, time 0600, forecast period 6: data added!
# 657: date 20240224, time 0600, forecast period 12: data added!
# 658: date 20240224, time 0600, forecast period 24: data added!
# 659: date 20240224, time 0600, forecast period 48: data added!
# 660: date 20240224, time 0600, forecast period 72: data added!
# 661: date 20240224, time 1200, forecast period 0: data added!
# 662: date 20240224, time 1200, forecast period 1: data added!
# 663: date 20240224, time 1200, forecast period 2: data added!
# 664: date 20240224, time 1200, forecast period 3: data added!
# 665: date 20240224, time 1200, forecast period 4: data added!
# 666: date 20240224, time 1200, forecast period 6: data added!
# 667: date 20240224, time 1200, forecast period 12: data added!
# 668: date 20240224, time 1200, forecast period 24: data added!
# 669: date 20240224, time 1200, forecast period 48: data added!
# 670: date 20240224, time 1200, forecast period 72: data added!
# 671: date 20240224, time 1800, forecast period 0: data added!
# 672: date 20240224, time 1800, forecast period 1: data added!
# 673: date 20240224, time 1800, forecast period 2: data added!
# 674: date 20240224, time 1800, forecast period 3: data added!
# 675: date 20240224, time 1800, forecast period 4: data added!
# 676: date 20240224, time 1800, forecast period 6: data added!
# 677: date 20240224, time 1800, forecast period 12: data added!
# 678: date 20240224, time 1800, forecast period 24: data added!
# 679: date 20240224, time 1800, forecast period 48: data added!
# 680: date 20240224, time 1800, forecast period 72: data added!
# 681: date 20240225, time 0000, forecast period 0: data added!
# 682: date 20240225, time 0000, forecast period 1: data added!
# 683: date 20240225, time 0000, forecast period 2: data added!
# 684: date 20240225, time 0000, forecast period 3: data added!
# 685: date 20240225, time 0000, forecast period 4: data added!
# 686: date 20240225, time 0000, forecast period 6: data added!
# 687: date 20240225, time 0000, forecast period 12: data added!
# 688: date 20240225, time 0000, forecast period 24: data added!
# 689: date 20240225, time 0000, forecast period 48: data added!
# 690: date 20240225, time 0000, forecast period 72: data added!
# 691: date 20240225, time 0600, forecast period 0: data added!
# 692: date 20240225, time 0600, forecast period 1: data added!
# 693: date 20240225, time 0600, forecast period 2: data added!
# 694: date 20240225, time 0600, forecast period 3: data added!
# 695: date 20240225, time 0600, forecast period 4: data added!
# 696: date 20240225, time 0600, forecast period 6: data added!
# 697: date 20240225, time 0600, forecast period 12: data added!
# 698: date 20240225, time 0600, forecast period 24: data added!
# 699: date 20240225, time 0600, forecast period 48: data added!
# 700: date 20240225, time 0600, forecast period 72: data added!
# 701: date 20240225, time 1200, forecast period 0: data added!
# 702: date 20240225, time 1200, forecast period 1: data added!
# 703: date 20240225, time 1200, forecast period 2: data added!
# 704: date 20240225, time 1200, forecast period 3: data added!
# 705: date 20240225, time 1200, forecast period 4: data added!
# 706: date 20240225, time 1200, forecast period 6: data added!
# 707: date 20240225, time 1200, forecast period 12: data added!
# 708: date 20240225, time 1200, forecast period 24: data added!
# 709: date 20240225, time 1200, forecast period 48: data added!
# 710: date 20240225, time 1200, forecast period 72: data added!
# 711: date 20240225, time 1800, forecast period 0: data added!
# 712: date 20240225, time 1800, forecast period 1: data added!
# 713: date 20240225, time 1800, forecast period 2: data added!
# 714: date 20240225, time 1800, forecast period 3: data added!
# 715: date 20240225, time 1800, forecast period 4: data added!
# 716: date 20240225, time 1800, forecast period 6: data added!
# 717: date 20240225, time 1800, forecast period 12: data added!
# 718: date 20240225, time 1800, forecast period 24: data added!
# 719: date 20240225, time 1800, forecast period 48: data added!
# 720: date 20240225, time 1800, forecast period 72: data added!
# 721: date 20240226, time 0000, forecast period 0: data added!
# 722: date 20240226, time 0000, forecast period 1: data added!
# 723: date 20240226, time 0000, forecast period 2: data added!
# 724: date 20240226, time 0000, forecast period 3: data added!
# 725: date 20240226, time 0000, forecast period 4: data added!
# 726: date 20240226, time 0000, forecast period 6: data added!
# 727: date 20240226, time 0000, forecast period 12: data added!
# 728: date 20240226, time 0000, forecast period 24: data added!
# 729: date 20240226, time 0000, forecast period 48: data added!
# 730: date 20240226, time 0000, forecast period 72: data added!
# 731: date 20240226, time 0600, forecast period 0: data added!
# 732: date 20240226, time 0600, forecast period 1: data added!
# 733: date 20240226, time 0600, forecast period 2: data added!
# 734: date 20240226, time 0600, forecast period 3: data added!
# 735: date 20240226, time 0600, forecast period 4: data added!
# 736: date 20240226, time 0600, forecast period 6: data added!
# 737: date 20240226, time 0600, forecast period 12: data added!
# 738: date 20240226, time 0600, forecast period 24: data added!
# 739: date 20240226, time 0600, forecast period 48: data added!
# 740: date 20240226, time 0600, forecast period 72: data added!
# 741: date 20240226, time 1200, forecast period 0: data added!
# 742: date 20240226, time 1200, forecast period 1: data added!
# 743: date 20240226, time 1200, forecast period 2: data added!
# 744: date 20240226, time 1200, forecast period 3: data added!
# 745: date 20240226, time 1200, forecast period 4: data added!
# 746: date 20240226, time 1200, forecast period 6: data added!
# 747: date 20240226, time 1200, forecast period 12: data added!
# 748: date 20240226, time 1200, forecast period 24: data added!
# 749: date 20240226, time 1200, forecast period 48: data added!
# 750: date 20240226, time 1200, forecast period 72: data added!
# 751: date 20240226, time 1800, forecast period 0: data added!
# 752: date 20240226, time 1800, forecast period 1: data added!
# 753: date 20240226, time 1800, forecast period 2: data added!
# 754: date 20240226, time 1800, forecast period 3: data added!
# 755: date 20240226, time 1800, forecast period 4: data added!
# 756: date 20240226, time 1800, forecast period 6: data added!
# 757: date 20240226, time 1800, forecast period 12: data added!
# 758: date 20240226, time 1800, forecast period 24: data added!
# 759: date 20240226, time 1800, forecast period 48: data added!
# 760: date 20240226, time 1800, forecast period 72: data added!
# 761: date 20240227, time 0000, forecast period 0: data added!
# 762: date 20240227, time 0000, forecast period 1: data added!
# 763: date 20240227, time 0000, forecast period 2: data added!
# 764: date 20240227, time 0000, forecast period 3: data added!
# 765: date 20240227, time 0000, forecast period 4: data added!
# 766: date 20240227, time 0000, forecast period 6: data added!
# 767: date 20240227, time 0000, forecast period 12: data added!
# 768: date 20240227, time 0000, forecast period 24: data added!
# 769: date 20240227, time 0000, forecast period 48: data added!
# 770: date 20240227, time 0000, forecast period 72: data added!
# ...
# 1070: date 20240305, time 1200, forecast period 72: data added!
# 1071: date 20240305, time 1800, forecast period 0: data added!
# 1072: date 20240305, time 1800, forecast period 1: data added!
# 1073: date 20240305, time 1800, forecast period 2: data added!
# 1074: date 20240305, time 1800, forecast period 3: data added!
# 1075: date 20240305, time 1800, forecast period 4: data added!
# 1076: date 20240305, time 1800, forecast period 6: data added!
# 1077: date 20240305, time 1800, forecast period 12: data added!
# 1078: date 20240305, time 1800, forecast period 24: data added!
# 1079: date 20240305, time 1800, forecast period 48: data added!
# 1080: date 20240305, time 1800, forecast period 72: data added!
# 1081: date 20240306, time 0000, forecast period 0: data added!
# 1082: date 20240306, time 0000, forecast period 1: data added!
# 1083: date 20240306, time 0000, forecast period 2: data added!
# 1084: date 20240306, time 0000, forecast period 3: data added!
# 1085: date 20240306, time 0000, forecast period 4: data added!
# 1086: date 20240306, time 0000, forecast period 6: data added!
# 1087: date 20240306, time 0000, forecast period 12: data added!
# 1088: date 20240306, time 0000, forecast period 24: data added!
# 1089: date 20240306, time 0000, forecast period 48: data added!
# 1090: date 20240306, time 0000, forecast period 72: data added!
# 1091: date 20240306, time 0600, forecast period 0: data added!
# 1092: date 20240306, time 0600, forecast period 1: data added!
# 1093: date 20240306, time 0600, forecast period 2: data added!
# 1094: date 20240306, time 0600, forecast period 3: data added!
# 1095: date 20240306, time 0600, forecast period 4: data added!
# 1096: date 20240306, time 0600, forecast period 6: data added!
# 1097: date 20240306, time 0600, forecast period 12: data added!
# 1098: date 20240306, time 0600, forecast period 24: data added!
# 1099: date 20240306, time 0600, forecast period 48: data added!
# 1100: date 20240306, time 0600, forecast period 72: data added!
# 1101: date 20240306, time 1200, forecast period 0: data added!
# 1102: date 20240306, time 1200, forecast period 1: data added!
# 1103: date 20240306, time 1200, forecast period 2: data added!
# 1104: date 20240306, time 1200, forecast period 3: data added!
# 1105: date 20240306, time 1200, forecast period 4: data added!
# 1106: date 20240306, time 1200, forecast period 6: data added!
# 1107: date 20240306, time 1200, forecast period 12: data added!
# 1108: date 20240306, time 1200, forecast period 24: data added!
# 1109: date 20240306, time 1200, forecast period 48: data added!
# 1110: date 20240306, time 1200, forecast period 72: data added!
# 1111: date 20240306, time 1800, forecast period 0: data added!
# 1112: date 20240306, time 1800, forecast period 1: data added!
# 1113: date 20240306, time 1800, forecast period 2: data added!
# 1114: date 20240306, time 1800, forecast period 3: data added!
# 1115: date 20240306, time 1800, forecast period 4: data added!
# 1116: date 20240306, time 1800, forecast period 6: no data found
# 1117: date 20240306, time 1800, forecast period 12: data added!
# 1118: date 20240306, time 1800, forecast period 24: data added!
# 1119: date 20240306, time 1800, forecast period 48: data added!
# 1120: date 20240306, time 1800, forecast period 72: data added!
# 1121: date 20240307, time 0000, forecast period 0: data added!
# 1122: date 20240307, time 0000, forecast period 1: data added!
# 1123: date 20240307, time 0000, forecast period 2: data added!
# 1124: date 20240307, time 0000, forecast period 3: data added!
# 1125: date 20240307, time 0000, forecast period 4: data added!
# 1126: date 20240307, time 0000, forecast period 6: data added!
# 1127: date 20240307, time 0000, forecast period 12: data added!
# 1128: date 20240307, time 0000, forecast period 24: data added!
# 1129: date 20240307, time 0000, forecast period 48: data added!
# 1130: date 20240307, time 0000, forecast period 72: data added!
# 1131: date 20240307, time 0600, forecast period 0: data added!
# 1132: date 20240307, time 0600, forecast period 1: data added!
# 1133: date 20240307, time 0600, forecast period 2: data added!
# 1134: date 20240307, time 0600, forecast period 3: data added!
# 1135: date 20240307, time 0600, forecast period 4: data added!
# 1136: date 20240307, time 0600, forecast period 6: data added!
# 1137: date 20240307, time 0600, forecast period 12: data added!
# 1138: date 20240307, time 0600, forecast period 24: data added!
# 1139: date 20240307, time 0600, forecast period 48: data added!
# 1140: date 20240307, time 0600, forecast period 72: data added!
# 1141: date 20240307, time 1200, forecast period 0: data added!
# 1142: date 20240307, time 1200, forecast period 1: data added!
# 1143: date 20240307, time 1200, forecast period 2: data added!
# 1144: date 20240307, time 1200, forecast period 3: data added!
# 1145: date 20240307, time 1200, forecast period 4: data added!
# 1146: date 20240307, time 1200, forecast period 6: data added!
# 1147: date 20240307, time 1200, forecast period 12: data added!
# 1148: date 20240307, time 1200, forecast period 24: data added!
# 1149: date 20240307, time 1200, forecast period 48: data added!
# 1150: date 20240307, time 1200, forecast period 72: data added!
# 1151: date 20240307, time 1800, forecast period 0: data added!
# 1152: date 20240307, time 1800, forecast period 1: data added!
# 1153: date 20240307, time 1800, forecast period 2: data added!
# 1154: date 20240307, time 1800, forecast period 3: data added!
# 1155: date 20240307, time 1800, forecast period 4: data added!
# 1156: date 20240307, time 1800, forecast period 6: data added!
# 1157: date 20240307, time 1800, forecast period 12: data added!
# 1158: date 20240307, time 1800, forecast period 24: data added!
# 1159: date 20240307, time 1800, forecast period 48: data added!
# 1160: date 20240307, time 1800, forecast period 72: data added!
# 1161: date 20240308, time 0000, forecast period 0: data added!
# 1162: date 20240308, time 0000, forecast period 1: data added!
# 1163: date 20240308, time 0000, forecast period 2: data added!
# 1164: date 20240308, time 0000, forecast period 3: data added!
# 1165: date 20240308, time 0000, forecast period 4: data added!
# 1166: date 20240308, time 0000, forecast period 6: data added!
# 1167: date 20240308, time 0000, forecast period 12: data added!
# 1168: date 20240308, time 0000, forecast period 24: data added!
# 1169: date 20240308, time 0000, forecast period 48: data added!
# 1170: date 20240308, time 0000, forecast period 72: data added!
# 1171: date 20240308, time 0600, forecast period 0: data added!
# 1172: date 20240308, time 0600, forecast period 1: data added!
# 1173: date 20240308, time 0600, forecast period 2: data added!
# 1174: date 20240308, time 0600, forecast period 3: data added!
# 1175: date 20240308, time 0600, forecast period 4: data added!
# 1176: date 20240308, time 0600, forecast period 6: data added!
# 1177: date 20240308, time 0600, forecast period 12: data added!
# 1178: date 20240308, time 0600, forecast period 24: data added!
# 1179: date 20240308, time 0600, forecast period 48: data added!
# 1180: date 20240308, time 0600, forecast period 72: data added!
# 1181: date 20240308, time 1200, forecast period 0: data added!
# 1182: date 20240308, time 1200, forecast period 1: data added!
# 1183: date 20240308, time 1200, forecast period 2: data added!
# 1184: date 20240308, time 1200, forecast period 3: data added!
# 1185: date 20240308, time 1200, forecast period 4: data added!
# 1186: date 20240308, time 1200, forecast period 6: data added!
# 1187: date 20240308, time 1200, forecast period 12: data added!
# 1188: date 20240308, time 1200, forecast period 24: data added!
# 1189: date 20240308, time 1200, forecast period 48: data added!
# 1190: date 20240308, time 1200, forecast period 72: data added!
# 1191: date 20240308, time 1800, forecast period 0: data added!
# 1192: date 20240308, time 1800, forecast period 1: data added!
# 1193: date 20240308, time 1800, forecast period 2: data added!
# 1194: date 20240308, time 1800, forecast period 3: data added!
# 1195: date 20240308, time 1800, forecast period 4: data added!
# 1196: date 20240308, time 1800, forecast period 6: data added!
# 1197: date 20240308, time 1800, forecast period 12: data added!
# 1198: date 20240308, time 1800, forecast period 24: data added!
# 1199: date 20240308, time 1800, forecast period 48: data added!
# 1200: date 20240308, time 1800, forecast period 72: data added!
# 1201: date 20240309, time 0000, forecast period 0: data added!
# 1202: date 20240309, time 0000, forecast period 1: data added!
# 1203: date 20240309, time 0000, forecast period 2: data added!
# 1204: date 20240309, time 0000, forecast period 3: data added!
# 1205: date 20240309, time 0000, forecast period 4: data added!
# 1206: date 20240309, time 0000, forecast period 6: data added!
# 1207: date 20240309, time 0000, forecast period 12: data added!
# 1208: date 20240309, time 0000, forecast period 24: data added!
# 1209: date 20240309, time 0000, forecast period 48: data added!
# 1210: date 20240309, time 0000, forecast period 72: data added!
# 1211: date 20240309, time 0600, forecast period 0: data added!
# 1212: date 20240309, time 0600, forecast period 1: data added!
# 1213: date 20240309, time 0600, forecast period 2: data added!
# 1214: date 20240309, time 0600, forecast period 3: data added!
# 1215: date 20240309, time 0600, forecast period 4: data added!
# 1216: date 20240309, time 0600, forecast period 6: data added!
# 1217: date 20240309, time 0600, forecast period 12: data added!
# 1218: date 20240309, time 0600, forecast period 24: data added!
# 1219: date 20240309, time 0600, forecast period 48: data added!
# 1220: date 20240309, time 0600, forecast period 72: data added!
# 1221: date 20240309, time 1200, forecast period 0: data added!
# 1222: date 20240309, time 1200, forecast period 1: data added!
# 1223: date 20240309, time 1200, forecast period 2: data added!
# 1224: date 20240309, time 1200, forecast period 3: data added!
# 1225: date 20240309, time 1200, forecast period 4: data added!
# 1226: date 20240309, time 1200, forecast period 6: data added!
# 1227: date 20240309, time 1200, forecast period 12: data added!
# 1228: date 20240309, time 1200, forecast period 24: data added!
# 1229: date 20240309, time 1200, forecast period 48: data added!
# 1230: date 20240309, time 1200, forecast period 72: data added!
# 1231: date 20240309, time 1800, forecast period 0: data added!
# 1232: date 20240309, time 1800, forecast period 1: data added!
# 1233: date 20240309, time 1800, forecast period 2: data added!
# 1234: date 20240309, time 1800, forecast period 3: data added!
# 1235: date 20240309, time 1800, forecast period 4: data added!
# 1236: date 20240309, time 1800, forecast period 6: data added!
# 1237: date 20240309, time 1800, forecast period 12: data added!
# 1238: date 20240309, time 1800, forecast period 24: data added!
# 1239: date 20240309, time 1800, forecast period 48: data added!
# 1240: date 20240309, time 1800, forecast period 72: data added!
# 1241: date 20240310, time 0000, forecast period 0: data added!
# 1242: date 20240310, time 0000, forecast period 1: data added!
# 1243: date 20240310, time 0000, forecast period 2: data added!
# 1244: date 20240310, time 0000, forecast period 3: data added!
# 1245: date 20240310, time 0000, forecast period 4: data added!
# 1246: date 20240310, time 0000, forecast period 6: data added!
# 1247: date 20240310, time 0000, forecast period 12: data added!
# 1248: date 20240310, time 0000, forecast period 24: data added!
# 1249: date 20240310, time 0000, forecast period 48: data added!
# 1250: date 20240310, time 0000, forecast period 72: data added!
# 1251: date 20240310, time 0600, forecast period 0: data added!
# 1252: date 20240310, time 0600, forecast period 1: data added!
# 1253: date 20240310, time 0600, forecast period 2: data added!
# 1254: date 20240310, time 0600, forecast period 3: data added!
# 1255: date 20240310, time 0600, forecast period 4: data added!
# 1256: date 20240310, time 0600, forecast period 6: data added!
# 1257: date 20240310, time 0600, forecast period 12: data added!
# 1258: date 20240310, time 0600, forecast period 24: data added!
# 1259: date 20240310, time 0600, forecast period 48: data added!
# 1260: date 20240310, time 0600, forecast period 72: data added!
# 1261: date 20240310, time 1200, forecast period 0: data added!
# 1262: date 20240310, time 1200, forecast period 1: data added!
# 1263: date 20240310, time 1200, forecast period 2: data added!
# 1264: date 20240310, time 1200, forecast period 3: data added!
# 1265: date 20240310, time 1200, forecast period 4: data added!
# 1266: date 20240310, time 1200, forecast period 6: data added!
# 1267: date 20240310, time 1200, forecast period 12: data added!
# 1268: date 20240310, time 1200, forecast period 24: data added!
# 1269: date 20240310, time 1200, forecast period 48: data added!
# 1270: date 20240310, time 1200, forecast period 72: data added!
# 1271: date 20240310, time 1800, forecast period 0: data added!
# 1272: date 20240310, time 1800, forecast period 1: data added!
# 1273: date 20240310, time 1800, forecast period 2: data added!
# 1274: date 20240310, time 1800, forecast period 3: data added!
# 1275: date 20240310, time 1800, forecast period 4: data added!
# 1276: date 20240310, time 1800, forecast period 6: data added!
# 1277: date 20240310, time 1800, forecast period 12: data added!
# 1278: date 20240310, time 1800, forecast period 24: data added!
# 1279: date 20240310, time 1800, forecast period 48: data added!
# 1280: date 20240310, time 1800, forecast period 72: data added!
# 1281: date 20240311, time 0000, forecast period 0: data added!
# 1282: date 20240311, time 0000, forecast period 1: data added!
# 1283: date 20240311, time 0000, forecast period 2: data added!
# 1284: date 20240311, time 0000, forecast period 3: data added!
# 1285: date 20240311, time 0000, forecast period 4: data added!
# 1286: date 20240311, time 0000, forecast period 6: data added!
# 1287: date 20240311, time 0000, forecast period 12: data added!
# 1288: date 20240311, time 0000, forecast period 24: data added!
# 1289: date 20240311, time 0000, forecast period 48: data added!
# 1290: date 20240311, time 0000, forecast period 72: data added!
# 1291: date 20240311, time 0600, forecast period 0: data added!
# 1292: date 20240311, time 0600, forecast period 1: data added!
# 1293: date 20240311, time 0600, forecast period 2: data added!
# 1294: date 20240311, time 0600, forecast period 3: data added!
# 1295: date 20240311, time 0600, forecast period 4: data added!
# 1296: date 20240311, time 0600, forecast period 6: data added!
# 1297: date 20240311, time 0600, forecast period 12: data added!
# 1298: date 20240311, time 0600, forecast period 24: data added!
# 1299: date 20240311, time 0600, forecast period 48: data added!
# 1300: date 20240311, time 0600, forecast period 72: data added!
# 1301: date 20240311, time 1200, forecast period 0: data added!
# 1302: date 20240311, time 1200, forecast period 1: data added!
# 1303: date 20240311, time 1200, forecast period 2: data added!
# 1304: date 20240311, time 1200, forecast period 3: data added!
# 1305: date 20240311, time 1200, forecast period 4: data added!
# 1306: date 20240311, time 1200, forecast period 6: data added!
# 1307: date 20240311, time 1200, forecast period 12: data added!
# 1308: date 20240311, time 1200, forecast period 24: data added!
# 1309: date 20240311, time 1200, forecast period 48: data added!
# 1310: date 20240311, time 1200, forecast period 72: data added!
# 1311: date 20240311, time 1800, forecast period 0: data added!
# 1312: date 20240311, time 1800, forecast period 1: data added!
# 1313: date 20240311, time 1800, forecast period 2: data added!
# 1314: date 20240311, time 1800, forecast period 3: data added!
# 1315: date 20240311, time 1800, forecast period 4: data added!
# 1316: date 20240311, time 1800, forecast period 6: data added!
# 1317: date 20240311, time 1800, forecast period 12: data added!
# 1318: date 20240311, time 1800, forecast period 24: data added!
# 1319: date 20240311, time 1800, forecast period 48: data added!
# 1320: date 20240311, time 1800, forecast period 72: data added!
# Done! 1318 files successfully added.

# %%
# Crate dataframe for nam data
nam_wind_data_df = pd.DataFrame(nam_wind_data, columns=['time_utc','forecast_period','wspd','wdr','welv','temp_C','kinetic_e'])
nam_wind_data_df = nam_wind_data_df.sort_values(by=['time_utc', 'forecast_period'])
nam_wind_data_df
# Out:
#                 time_utc forecast_period      wspd         wdr      welv  \
# 0    2024-02-08 00:00:00             000  4.856055   53.385763 -0.148575
# 1    2024-02-08 00:00:00             001  4.419276   45.718757  0.144892
# 2    2024-02-08 00:00:00             002  3.942619   36.174609 -0.187564
# 3    2024-02-08 00:00:00             003  4.133296   24.822946  0.279599
# 4    2024-02-08 00:00:00             004  4.535726   15.952962 -0.101502
# ...                  ...             ...       ...         ...       ...
# 1313 2024-03-11 18:00:00             006  6.680576  275.817073 -0.028047
# 1314 2024-03-11 18:00:00             012  6.595477  281.342438 -0.183030
# 1315 2024-03-11 18:00:00             024  5.135105  143.975032 -0.115949
# 1316 2024-03-11 18:00:00             048  3.347656  281.716584  0.175220
# 1317 2024-03-11 18:00:00             072  5.790267  350.723248  0.101881
#
#         temp_C  kinetic_e
# 0    -0.297461        0.6
# 1    -0.441577        0.5
# 2    -0.437842        0.4
# 3    -0.465015        0.4
# 4    -0.503418        0.5
# ...        ...        ...
# 1313  1.159805        0.3
# 1314 -2.321797        0.1
# 1315  8.957837        1.1
# 1316  4.328857        0.6
# 1317  0.988306        0.9
#
# [1318 rows x 7 columns]

# %% [markdown]
# # Finally, save the data into a csv file

# %%
# Save nam data into a csv
nam_wind_data_df.to_csv('nam_wind_data.csv', index=False)
